# %% [markdown]
# EDA and Feature Engineering of google play store dataset

# %% [markdown]
# 1. Problem statement. Todat 1.85 million different apps are available for users to download. Android users gave even more from which to choose with 2.56 million avaible through the Google plat store. These apps have come to play a huge role in the way we live our lives today. Our objective is to finf th emost popular category find the largerst number of installs, the app with largest size, etc
#
# The data consists of 20 cokumns and 10841 rows
