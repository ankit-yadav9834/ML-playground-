# %% [markdown]
# Abstraction is the concept of hiding the complex implementation details and showing only the necessary features of an object. This helps in reducing programming complexity and efforts.

# %%
from abc import ABC, abstractmethod

# define abstract BASE class 

class Vehicle(ABC):
    def drive(self):
        print("the vehicle is used for driving")

    @abstractmethod
    def start_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        print("engine started ")

    def operate_pahiya(vehicle):
        vehicle.start_engine()
        vehicle.drive()

    car = Car()
    operate_pahiya(car)
# Out:
# engine started
# the vehicle is used for driving

# %% [markdown]
# Uper wle code me hamne abstarction dekha usme hamne abc methods se abstraction sikha
#
# hamne ye dekha ki Car wle classs me hame complex details pta hi ni hia mtlb ki ab ye car h , truck , bus h , hme usse mtlb nhi hai ham bs operate_pahiya function dia ab bs ye janega ki start engine aur vehivle drive usse ni pta kya hai bike h ya bus ya car ya truck
