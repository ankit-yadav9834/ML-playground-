# %% [markdown]
# Encapsulation and Abstraction
#
# Encapsulation and abstraction are twwo fundamental principles of OOP that help in designing robust, maintaince, and reusable code. Encapsulation involves bundling data and methods that operates on the data within a single unit, while abstraction involves hiding complex implementation details and exposing only the neccessary features.

# %% [markdown]
# Encapsulation
#
# Encapsulation is the concept of wrapping data (variables) and methods (functions) together as a single unit. It restricts direct access to some of the object's components, which is a means of prevebnting accidental interference and misuse of the data.

# %%
# Encapsulation with Getter and Setter methods

# Public, protected and private variables 

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age # this is public varaibles 
        
def get_name(person):
    return person.name

def get_age(person):
    return person.age


person = Person("Krish ", 25) 
get_name(person)
get_age(person)
# Out:
# 25

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
# Encapsulation with Getter and Setter methods
# Public, protected and private variables 

class Person:
    def __init__(self, name, age, gender):
        self.__name = name
        self.__age = age # this is private varaibles
        self.gender= gender 


def get_name (person):
    return person._Person__name

def get_age(person):
    return person.Person_age


person = Person("krish", 25,"M")
get_name(person)
# Out:
# 'krish'

# %%
person = Person("ABC", 52, "Mla")
dir(person)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender']

# %%
# Public, protected and private variables 

class Person:
    def __init__(self, name, age, gender):
        self._name = name
        self._age = age # this is protected varaibles
        self.gender= gender 


class Employee(Person):
    def __init__(self, name, age, gender):
        super().__init__(name, age, gender)


employee = Employee("Krsfs", 24, "M")
print(employee._age) # private variables
print(employee._name) # private variables
print(employee.gender) # public variables
# Out:
# 24
# Krsfs
# M

# %%
# Eancapsulation with getter and setter 

class Person:
    def __init__(self, name, age):
        self.__name = name ## private variable 
        self.__age = age 

    ##  getter method for name 
    def get_name(self):  ## We are retriving a data 
        return self.__name
    

    ## setter method for name 
    def set_name(self, name): ## we are changing a data
        self.__name = name 

     ##  getter method for age 
    def get_age(self):  ## We are retriving a data 
        return self.__age
    
     ## setter method for name 
    def set_age(self, age): ## we are changing a data
        if age>0:
            self.__age = age
        else:
            print("Enter the valid age")


person = Person("and", 34)

## access and modify private variable using getter and setter 

print(person.get_name())
print(person.get_age())

person.set_age(82)
print(person.get_age())

person.set_name("Ankit")
print(person.get_name())

person.set_age(-85)
# Out:
# and
# 34
# 82
# Ankit
# Enter the valid age
