# %% [markdown]
# Streamlit is a open source framework for machine learning and data science projects. It allows you to create beautiful web applications for your machine leanrning and data science projects with simple python.
