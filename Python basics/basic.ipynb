# %%
## basic syntax
## oython is a case sensitive 

name = "Ankit"
Name = " Yadav "

print(name)
print(Name)
# Out:
# Ankit
#  Yadav

# %%
## indentation 
##Python uses Indentation for block of codes. (uses for the structure and hierarchhy of code)

age =32
if age> 30:
    print(age)

print(age)
# Out:
# 32
# 32

# %%
## line continuation to continue the code jab hame code ko dusre line me lkhna ho tb ham ise use krre hai
total = 1+2+3+4+5+5+6+7+5+8+7+85+5+4+8+5+\
4+5+8
print(total)
# Out:
# 177

# %%
## multiple statenebts in a single line
x=5;y=58;z=85
print(z)
# Out:
# 85

# %%
## understand semantics in Python 
# variable assignment 

age =32 ## age is integer 
name = " ankit yadav"
type(age)
type(name)
# Out:
# str

# %%
## type inference
var = 30
print(type(var))

var = "ankit"
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## name error

a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 ## name error
# ----> 3 a = b
#
# NameError: name 'b' is not defined

# %%
## code example of indentation

if True:
    print("this is my correct indendation ")
    if False:
        print("this is not print")

    print("this will print")
print("poutsoi")
# Out:
# this is my correct indendation
# this will print
# poutsoi
